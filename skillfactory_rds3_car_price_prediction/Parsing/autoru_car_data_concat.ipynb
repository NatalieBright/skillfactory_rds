# %%
import pandas as pd

# %%
data_list = ['data_prt_1.csv', 'data_prt_2.csv', 'data_prt_3.csv', 
             'data_prt_4.csv', 'data_prt_5.csv', 'data_prt_6.csv', 
             'data_prt_7.csv', 'data_prt_8.csv', 'data_prt_9.csv',
             'data_prt_10.csv', 'data_prt_11.csv', 'data_prt_12.csv',
             'data_prt_13.csv', 'data_prt_14.csv', 'data_prt_15.csv']

# %%
cars = pd.DataFrame()

# Объединяем данные в один датафрейм
for data in data_list:
    df_temp = pd.read_csv(data)
    cars = pd.concat([cars,df_temp], sort=False, ignore_index=True)
    
# Удаляем лишние данные
cars = cars.drop(columns=['Unnamed: 0', 'Обмен', 'Гарантия'])

# %%
cars.to_csv('cars.csv', index=False)

# %%
cars
# Out:
#                                       name  год выпуска      Пробег  \
# 0                  525E 2.7 MT (125 л.с.)        1986.0  220 000 км
# 1                  525i 2.5 MT (170 л.с.)        1988.0  300 000 км
# 2                  318i 1.8 MT (115 л.с.)        1994.0  350 000 км
# 3                  520i 2.0 MT (150 л.с.)        1992.0  100 000 км
# 4                  520i 2.0 MT (125 л.с.)        1982.0  250 000 км
# ...                                    ...          ...         ...
# 7031  750Ld xDrive 3.0d AT (400 л.с.) 4WD        2019.0       31 км
# 7032    Competition 4.4 AT (625 л.с.) 4WD        2019.0      200 км
# 7033  M760Li xDrive 6.6 AT (609 л.с.) 4WD        2019.0        7 км
# 7034                    4.9 MT (400 л.с.)        2000.0   14 000 км
# 7035    Competition 4.4 AT (625 л.с.) 4WD        2020.0        1 км
#
#           Кузов         Цвет                  Двигатель           Налог  \
# 0         седан   золотистый  2.7 л / 125 л.с. / Бензин   3 125 ₽ / год
# 1         седан        серый  2.5 л / 170 л.с. / Бензин   7 650 ₽ / год
# 2         седан      зелёный  1.8 л / 115 л.с. / Бензин   3 910 ₽ / год
# 3         седан       чёрный  2.0 л / 150 л.с. / Бензин   5 250 ₽ / год
# 4         седан        белый  2.0 л / 125 л.с. / Бензин   3 125 ₽ / год
# ...         ...          ...                        ...             ...
# 7031      седан       чёрный  3.0 л / 400 л.с. / Дизель  60 000 ₽ / год
# 7032       купе       чёрный  4.4 л / 625 л.с. / Бензин  93 750 ₽ / год
# 7033      седан        синий  6.6 л / 609 л.с. / Бензин  91 350 ₽ / год
# 7034  кабриолет  серебристый  4.9 л / 400 л.с. / Бензин  60 000 ₽ / год
# 7035      седан      зелёный  4.4 л / 625 л.с. / Бензин             NaN
#
#              Коробка  Привод   Руль           Состояние    Владельцы  \
# 0       механическая  задний  Левый  Не требует ремонта  2 владельца
# 1       механическая  задний  Левый  Не требует ремонта  3 или более
# 2       механическая  задний  Левый  Не требует ремонта  3 или более
# 3       механическая  задний  Левый  Не требует ремонта  3 или более
# 4       механическая  задний  Левый  Не требует ремонта   1 владелец
# ...              ...     ...    ...                 ...          ...
# 7031  автоматическая  полный  Левый  Не требует ремонта   1 владелец
# 7032  автоматическая  полный  Левый  Не требует ремонта   1 владелец
# 7033  автоматическая  полный  Левый  Не требует ремонта   1 владелец
# 7034    механическая  задний  Левый  Не требует ремонта  3 или более
# 7035  автоматическая  полный  Левый  Не требует ремонта   1 владелец
#
#            ПТС     Таможня                                       Комплектация  \
# 0     Оригинал  Растаможен                                                 []
# 1     Дубликат  Растаможен                                                 []
# 2     Дубликат  Растаможен                                                 []
# 3     Оригинал  Растаможен                                                 []
# 4          NaN         NaN                                                 []
# ...        ...         ...                                                ...
# 7031  Оригинал  Растаможен  ['Защита картера', 'Обвес кузова', 'Алькантара...
# 7032  Оригинал  Растаможен  ['Круиз-контроль', 'Мультифункциональное рулев...
# 7033  Оригинал  Растаможен  ['Солнцезащитная шторка на заднем стекле', 'То...
# 7034  Оригинал  Растаможен                                                 []
# 7035  Оригинал         NaN  ['Автоматический корректор фар', 'Система адап...
#
#               Цена numberOfDoors           Владение Статус
# 0         50 000 ₽             4                NaN    NaN
# 1         70 000 ₽             4                NaN    NaN
# 2         70 000 ₽             5          9 месяцев    NaN
# 3         70 000 ₽             4                NaN    NaN
# 4         70 000 ₽             4                NaN    NaN
# ...            ...           ...                ...    ...
# 7031  12 460 000 ₽             4                NaN    NaN
# 7032  12 600 000 ₽             2                NaN    NaN
# 7033  12 689 999 ₽             4                NaN    NaN
# 7034  14 000 000 ₽             2  5 лет и 8 месяцев    NaN
# 7035           NaN             4                NaN    NaN
#
# [7036 rows x 19 columns]

# %%
cars = pd.read_csv('cars.csv')
